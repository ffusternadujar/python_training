# %%
import os
os.listdir()
# Out:
# ['supermarkets.xlsx',
#  'supermarkets-commas.txt',
#  '.ipynb_checkpoints',
#  'data.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.ipynb',
#  'supermarkets-semi-colons.txt']

# %%
import pandas

# %%
df=pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df=pandas.read_json("supermarkets.json")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df=pandas.read_excel("supermarkets.xlsx",sheet_name=0)
df
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df=pandas.read_csv("supermarkets-commas.txt")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df=pandas.read_csv("supermarkets-semi-colons.txt", sep=";")
df
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df = pandas.read_csv("data.txt", header=None)
df
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df.columns = ["ID", "Address", "City", "ZIP", "Country", "Name", "Employees"]
df
# Out:
#    ID          Address           City               ZIP Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df.set_index("ID")
# Out:
#             Address           City               ZIP Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df
# Out:
#    ID          Address           City               ZIP Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = df.set_index("ID")
df2
# Out:
#             Address           City               ZIP Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df.set_index("ID", inplace=True)
df
# Out:
#             Address           City               ZIP Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df.set_index("Address", inplace=True, drop=False)
df
# Out:
#                          Address           City               ZIP Country  \
# Address
# 3666 21st St        3666 21st St  San Francisco          CA 94114     USA
# 735 Dolores St    735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St          332 Hill St  San Francisco  California 94114     USA
# 3995 23rd St        3995 23rd St  San Francisco          CA 94114     USA
# 1056 Sanchez St  1056 Sanchez St  San Francisco        California     USA
# 551 Alvarado St  551 Alvarado St  San Francisco          CA 94114     USA
#
#                         Name  Employees
# Address
# 3666 21st St         Madeira          8
# 735 Dolores St   Bready Shop         15
# 332 Hill St      Super River         25
# 3995 23rd St      Ben's Shop         10
# 1056 Sanchez St      Sanchez         12
# 551 Alvarado St   Richvalley         20

# %%
df.set_index("Name", inplace=True, drop=False)
df
# Out:
#                      Address           City               ZIP Country  \
# Name
# Madeira         3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   735 Dolores St  San Francisco          CA 94119     USA
# Super River      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop      3995 23rd St  San Francisco          CA 94114     USA
# Sanchez      1056 Sanchez St  San Francisco        California     USA
# Richvalley   551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees
# Name
# Madeira          Madeira          8
# Bready Shop  Bready Shop         15
# Super River  Super River         25
# Ben's Shop    Ben's Shop         10
# Sanchez          Sanchez         12
# Richvalley    Richvalley         20

# %%
df.loc["Super River":"Sanchez", "Country":"Employees"]
# Out:
#             Country         Name  Employees
# Name
# Super River     USA  Super River         25
# Ben's Shop      USA   Ben's Shop         10
# Sanchez         USA      Sanchez         12

# %%
list(df.loc[:,"Employees"])
# Out:
# [8, 15, 25, 10, 12, 20]

# %%
df.iloc[2:5, 3:6]
# Out:
#             Country         Name  Employees
# Name
# Super River     USA  Super River         25
# Ben's Shop      USA   Ben's Shop         10
# Sanchez         USA      Sanchez         12

# %%
df.iloc[3, :]
# Out:
# Address       3995 23rd St
# City         San Francisco
# ZIP               CA 94114
# Country                USA
# Name            Ben's Shop
# Employees               10
# Name: Ben's Shop, dtype: object

# %%
df_del = df
df_del
# Out:
#                      Address           City               ZIP Country  \
# Name
# Madeira         3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   735 Dolores St  San Francisco          CA 94119     USA
# Super River      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop      3995 23rd St  San Francisco          CA 94114     USA
# Sanchez      1056 Sanchez St  San Francisco        California     USA
# Richvalley   551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees
# Name
# Madeira          Madeira          8
# Bready Shop  Bready Shop         15
# Super River  Super River         25
# Ben's Shop    Ben's Shop         10
# Sanchez          Sanchez         12
# Richvalley    Richvalley         20

# %%
df_del.drop("City",axis=1)
# Out:
#                      Address               ZIP Country         Name  Employees
# Name
# Madeira         3666 21st St          CA 94114     USA      Madeira          8
# Bready Shop   735 Dolores St          CA 94119     USA  Bready Shop         15
# Super River      332 Hill St  California 94114     USA  Super River         25
# Ben's Shop      3995 23rd St          CA 94114     USA   Ben's Shop         10
# Sanchez      1056 Sanchez St        California     USA      Sanchez         12
# Richvalley   551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
df_del.drop("Madeira", axis=0)
# Out:
#                      Address           City               ZIP Country  \
# Name
# Bready Shop   735 Dolores St  San Francisco          CA 94119     USA
# Super River      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop      3995 23rd St  San Francisco          CA 94114     USA
# Sanchez      1056 Sanchez St  San Francisco        California     USA
# Richvalley   551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees
# Name
# Bready Shop  Bready Shop         15
# Super River  Super River         25
# Ben's Shop    Ben's Shop         10
# Sanchez          Sanchez         12
# Richvalley    Richvalley         20

# %%
df_del.index[0:3]
# Out:
# Index(['Madeira', 'Bready Shop', 'Super River'], dtype='str', name='Name')

# %%
df_del.columns[0:3]
# Out:
# Index(['Address', 'City', 'ZIP'], dtype='str')

# %%
df_del.drop(df_del.columns[0:3], axis=1)
# Out:
#             Country         Name  Employees
# Name
# Madeira         USA      Madeira          8
# Bready Shop     USA  Bready Shop         15
# Super River     USA  Super River         25
# Ben's Shop      USA   Ben's Shop         10
# Sanchez         USA      Sanchez         12
# Richvalley      USA   Richvalley         20

# %%
df_del.iloc[0,3]
# Out:
# 'USA'

# %%
df["Continent"] = df["Country"].apply(lambda x: "North America" if x == "USA" else "Other")
df
# Out:
#                      Address           City               ZIP Country  \
# Name
# Madeira         3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   735 Dolores St  San Francisco          CA 94119     USA
# Super River      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop      3995 23rd St  San Francisco          CA 94114     USA
# Sanchez      1056 Sanchez St  San Francisco        California     USA
# Richvalley   551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees      Continent
# Name
# Madeira          Madeira          8  North America
# Bready Shop  Bready Shop         15  North America
# Super River  Super River         25  North America
# Ben's Shop    Ben's Shop         10  North America
# Sanchez          Sanchez         12  North America
# Richvalley    Richvalley         20  North America

# %%
df["Continent"] = df["Country"] + " Continent"

# %%
df
# Out:
#                      Address           City               ZIP Country  \
# Name
# Madeira         3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   735 Dolores St  San Francisco          CA 94119     USA
# Super River      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop      3995 23rd St  San Francisco          CA 94114     USA
# Sanchez      1056 Sanchez St  San Francisco        California     USA
# Richvalley   551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employees      Continent
# Name
# Madeira          Madeira          8  USA Continent
# Bready Shop  Bready Shop         15  USA Continent
# Super River  Super River         25  USA Continent
# Ben's Shop    Ben's Shop         10  USA Continent
# Sanchez          Sanchez         12  USA Continent
# Richvalley    Richvalley         20  USA Continent

# %%
df_t = df.T
df_t
# Out:
# Name             Madeira     Bready Shop       Super River     Ben's Shop  \
# Address     3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# City       San Francisco   San Francisco     San Francisco  San Francisco
# ZIP             CA 94114        CA 94119  California 94114       CA 94114
# Country              USA             USA               USA            USA
# Name             Madeira     Bready Shop       Super River     Ben's Shop
# Employees              8              15                25             10
# Continent  USA Continent   USA Continent     USA Continent  USA Continent
#
# Name               Sanchez       Richvalley
# Address    1056 Sanchez St  551 Alvarado St
# City         San Francisco    San Francisco
# ZIP             California         CA 94114
# Country                USA              USA
# Name               Sanchez       Richvalley
# Employees               12               20
# Continent    USA Continent    USA Continent

# %%
df_t["My Shop Name"] = ["My Address", "My City", "My State", "My Country", "My Shop Name", "10", "My Continent"]
df_t
# Out:
# Name             Madeira     Bready Shop       Super River     Ben's Shop  \
# Address     3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# City       San Francisco   San Francisco     San Francisco  San Francisco
# ZIP             CA 94114        CA 94119  California 94114       CA 94114
# Country              USA             USA               USA            USA
# Name             Madeira     Bready Shop       Super River     Ben's Shop
# Employees              8              15                25             10
# Continent  USA Continent   USA Continent     USA Continent  USA Continent
#
# Name               Sanchez       Richvalley  My Shop Name
# Address    1056 Sanchez St  551 Alvarado St    My Address
# City         San Francisco    San Francisco       My City
# ZIP             California         CA 94114      My State
# Country                USA              USA    My Country
# Name               Sanchez       Richvalley  My Shop Name
# ...

# %%
df = df_t.T
df
# Out:
#                       Address           City               ZIP     Country  \
# Name
# Madeira          3666 21st St  San Francisco          CA 94114         USA
# Bready Shop    735 Dolores St  San Francisco          CA 94119         USA
# Super River       332 Hill St  San Francisco  California 94114         USA
# Ben's Shop       3995 23rd St  San Francisco          CA 94114         USA
# Sanchez       1056 Sanchez St  San Francisco        California         USA
# Richvalley    551 Alvarado St  San Francisco          CA 94114         USA
# My Shop Name       My Address        My City          My State  My Country
#
#                       Name Employees      Continent
# Name
# Madeira            Madeira         8  USA Continent
# Bready Shop    Bready Shop        15  USA Continent
# Super River    Super River        25  USA Continent
# Ben's Shop      Ben's Shop        10  USA Continent
# Sanchez            Sanchez        12  USA Continent
# ...

# %%
import geopy
from geopy.geocoders import ArcGIS

# %%
nom=ArcGIS()
df.loc["Madeira","Address":"Country"]
# Out:
# Address     3666 21st St
# City       San Francisco
# ZIP             CA 94114
# Country              USA
# Name: Madeira, dtype: object

# %%
nom.geocode(df.loc["Madeira","Address":"Country"])
# Out:
# Location(3666 21st St, San Francisco, California, 94114, (37.75664822094, -122.429374802126, 0.0))

# %%
df["Latitude"] = (df["Address"] + "  , " + df["City"] + ", " + df["ZIP"]).apply(lambda x : nom.geocode(x).latitude)
df["Longitude"] = (df["Address"] + "  , " + df["City"] + ", " + df["ZIP"]).apply(lambda x : nom.geocode(x).longitude)
df
# Out:
#                       Address           City               ZIP     Country  \
# Name
# Madeira          3666 21st St  San Francisco          CA 94114         USA
# Bready Shop    735 Dolores St  San Francisco          CA 94119         USA
# Super River       332 Hill St  San Francisco  California 94114         USA
# Ben's Shop       3995 23rd St  San Francisco          CA 94114         USA
# Sanchez       1056 Sanchez St  San Francisco        California         USA
# Richvalley    551 Alvarado St  San Francisco          CA 94114         USA
# My Shop Name       My Address        My City          My State  My Country
#
#                       Name Employees      Continent   Latitude   Longitude
# Name
# Madeira            Madeira         8  USA Continent  37.756648 -122.429375
# Bready Shop    Bready Shop        15  USA Continent  37.757811 -122.425493
# Super River    Super River        25  USA Continent  37.755842 -122.428836
# ...

# %%
df
# Out:
#                       Address           City               ZIP     Country  \
# Name
# Madeira          3666 21st St  San Francisco          CA 94114         USA
# Bready Shop    735 Dolores St  San Francisco          CA 94119         USA
# Super River       332 Hill St  San Francisco  California 94114         USA
# Ben's Shop       3995 23rd St  San Francisco          CA 94114         USA
# Sanchez       1056 Sanchez St  San Francisco        California         USA
# Richvalley    551 Alvarado St  San Francisco          CA 94114         USA
# My Shop Name       My Address        My City          My State  My Country
#
#                       Name Employees      Continent   Latitude   Longitude
# Name
# Madeira            Madeira         8  USA Continent  37.756648 -122.429375
# Bready Shop    Bready Shop        15  USA Continent  37.757811 -122.425493
# Super River    Super River        25  USA Continent  37.755842 -122.428836
# ...
